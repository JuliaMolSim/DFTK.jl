# %% [markdown]
# # Geometry optimization
#
# We use DFTK and the [GeometryOptimization](https://github.com/JuliaMolSim/GeometryOptimization.jl/)
# package to find the minimal-energy bond length of the $H_2$ molecule.
# First we set up an appropriate `DFTKCalculator` (see AtomsCalculators integration),
# for which we use the LDA model just like in the Tutorial for silicon
# in combination with a pseudodojo pseudopotential (see Pseudopotentials).

# %%
using DFTK
using PseudoPotentialData

pseudopotentials = PseudoFamily("dojo.nc.sr.pbe.v0_4_1.oncvpsp3.standard.upf")
calc = DFTKCalculator(;
    model_kwargs = (; functionals=LDA(), pseudopotentials),  # model_DFT keyword arguments
    basis_kwargs = (; kgrid=[1, 1, 1], Ecut=10)  # PlaneWaveBasis keyword arguments
)
# Out:
# DFTKCalculator(functionals=Xc(lda_x, lda_c_pw), pseudopotentials=PseudoFamily("dojo.nc.sr.pbe.v0_4_1.oncvpsp3.standard.upf"), Ecut=10, kgrid=[1, 1, 1])

# %% [markdown]
# Next we set up an initial hydrogen molecule within a box of vacuum.
# We use the parameters of the
# [equivalent tutorial from ABINIT](https://docs.abinit.org/tutorial/base1/)
# and DFTK's AtomsBase integration to setup the hydrogen molecule.
# We employ a simulation box of 10 bohr times 10 bohr times 10 bohr and a
# pseudodojo pseudopotential.

# %%
using LinearAlgebra
using Unitful
using UnitfulAtomic

r0 = 1.4   # Initial bond length in Bohr
a  = 10.0  # Box size in Bohr

cell_vectors = [[a, 0, 0]u"bohr", [0, a, 0]u"bohr", [0, 0, a]u"bohr"]
h2_crude = periodic_system([:H => [0, 0, 0.]u"bohr",
                            :H => [r0, 0, 0]u"bohr"],
                           cell_vectors)
# Out:
# FlexibleSystem(H₂, periodicity = TTT):
#     cell_vectors      : [      10        0        0;
#                                 0       10        0;
#                                 0        0       10]u"a₀"
#
#     Atom(H,  [       0,        0,        0]u"a₀")
#     Atom(H,  [     1.4,        0,        0]u"a₀")

# %% [markdown]
# Finally we call `minimize_energy!` to start the geometry optimisation.
# We use `verbosity=2` to get some insight into the minimisation.
# With `verbosity=1` only a summarising table would be printed and with
# `verbosity=0` (default) the minimisation would be quiet.

# %%
using GeometryOptimization
results = minimize_energy!(h2_crude, calc; tol_forces=2e-6, verbosity=2)
nothing  # hide
# Out:
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.110679426978                   -0.82   0.80    7.0    4.07s
#   2   -1.117207156169       -2.19       -1.88   0.80    1.0    1.99s
#   3   -1.117251949735       -4.35       -2.73   0.80    1.0   50.6ms
#   4   -1.117252488489       -6.27       -3.61   0.80    1.0   17.2ms
#   5   -1.117252499474       -7.96       -4.04   0.80    1.0   22.8ms
#   6   -1.117252500801       -8.88       -5.05   0.80    1.0   17.8ms
#   7   -1.117252500844      -10.37       -5.57   0.80    1.0   18.2ms
#   8   -1.117252500846      -11.68       -6.46   0.80    2.0   22.6ms
#   9   -1.117252500846      -13.86       -6.91   0.80    1.0   20.5ms
#  10   -1.117252500846      -14.57       -7.89   0.80    1.0   20.4ms
#  11   -1.117252500846      -15.65       -8.25   0.80    2.0   22.4ms
#  12   -1.117252500846   +    -Inf       -8.83   0.80    1.0   20.5ms
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.117252500846                   -9.27   0.80    1.0    2.04s
#   2   -1.117252500846      -15.65      -10.33   0.80    1.0   16.7ms
#
# Geometry optimisation convergence (in atomic units)
# ┌─────┬─────────────────┬───────────┬────────────┬────────┐
# │   n │          Energy │ log10(ΔE) │ max(Force) │  Δtime │
# ├─────┼─────────────────┼───────────┼────────────┼────────┤
# │   0 │ -1.117252500846 │           │  0.0269316 │  18.9s │
# └─────┴─────────────────┴───────────┴────────────┴────────┘
#
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.117519304619                   -2.46   0.80    1.0   10.6ms
#   2   -1.117521893086       -5.59       -3.49   0.80    1.0   16.5ms
#   3   -1.117521920027       -7.57       -4.23   0.80    1.0   29.3ms
#   4   -1.117521920487       -9.34       -5.15   0.80    1.0   17.2ms
#   5   -1.117521920502      -10.81       -5.93   0.80    1.0   17.5ms
#   6   -1.117521920503      -12.17       -6.43   0.80    1.0   19.6ms
#   7   -1.117521920503      -13.36       -7.44   0.80    1.0   20.0ms
#   8   -1.117521920503      -15.18       -8.32   0.80    1.0   18.6ms
#   9   -1.117521920503      -14.95       -8.86   0.80    1.0   21.8ms
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.118248561952                   -1.69   0.80    1.0   15.4ms
#   2   -1.118340340237       -4.04       -2.70   0.80    1.0   18.0ms
#   3   -1.118341307403       -6.01       -3.44   0.80    1.0   18.1ms
#   4   -1.118341324844       -7.76       -4.36   0.80    1.0   17.0ms
#   5   -1.118341325428       -9.23       -5.12   0.80    1.0   18.8ms
#   6   -1.118341325455      -10.57       -5.62   0.80    1.0   19.1ms
#   7   -1.118341325457      -11.73       -6.68   0.80    1.0   19.9ms
#   8   -1.118341325457      -13.60       -7.58   0.80    1.0   20.6ms
#   9   -1.118341325457      -14.88       -8.12   0.80    1.0   20.7ms
#  10   -1.118341325457   +  -14.61       -8.55   0.80    1.0   20.7ms
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.118341325457                   -9.05   0.80    1.0   18.5ms
#   2   -1.118341325457      -15.35      -10.36   0.80    1.0   16.8ms
#
# ┌─────┬─────────────────┬───────────┬────────────┬────────┐
# │   n │          Energy │ log10(ΔE) │ max(Force) │  Δtime │
# ├─────┼─────────────────┼───────────┼────────────┼────────┤
# │   1 │ -1.118341325457 │     -2.96 │ 0.00297051 │  1.94s │
# └─────┴─────────────────┴───────────┴────────────┴────────┘
#
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.118348017619                   -3.09   0.80    1.0   11.4ms
#   2   -1.118348160867       -6.84       -4.11   0.80    1.0   38.0ms
#   3   -1.118348162344       -8.83       -4.86   0.80    1.0   16.8ms
#   4   -1.118348162370      -10.59       -5.78   0.80    1.0   21.7ms
#   5   -1.118348162371      -12.08       -6.55   0.80    1.0   17.4ms
#   6   -1.118348162371      -13.42       -7.04   0.80    1.0   19.6ms
#   7   -1.118348162371      -14.75       -8.13   0.80    1.0   19.9ms
#   8   -1.118348162371   +  -15.35       -8.95   0.80    1.0   19.9ms
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.118356019881                   -2.61   0.80    1.0   10.7ms
#   2   -1.118357382893       -5.87       -3.62   0.80    1.0   19.3ms
#   3   -1.118357396968       -7.85       -4.37   0.80    1.0   18.6ms
#   4   -1.118357397214       -9.61       -5.29   0.80    1.0   17.2ms
#   5   -1.118357397222      -11.10       -6.06   0.80    1.0   19.3ms
#   6   -1.118357397223      -12.45       -6.55   0.80    1.0   19.8ms
#   7   -1.118357397223      -13.60       -7.65   0.80    1.0   20.4ms
#   8   -1.118357397223   +  -15.35       -8.45   0.80    1.0   97.1ms
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.118357397223                   -9.24   0.80    1.0   10.6ms
#   2   -1.118357397223      -14.88       -9.82   0.80    1.0   16.9ms
#
# ┌─────┬─────────────────┬───────────┬────────────┬────────┐
# │   n │          Energy │ log10(ΔE) │ max(Force) │  Δtime │
# ├─────┼─────────────────┼───────────┼────────────┼────────┤
# │   2 │ -1.118357397223 │     -4.79 │ 4.47255e-5 │  1.22s │
# └─────┴─────────────────┴───────────┴────────────┴────────┘
#
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.118357398685                   -4.94   0.80    1.0   13.5ms
#   2   -1.118357398714      -10.54       -5.96   0.80    1.0   23.3ms
#   3   -1.118357398714      -12.52       -6.70   0.80    1.0   22.0ms
#   4   -1.118357398714      -14.05       -7.62   0.80    1.0   21.4ms
#   5   -1.118357398714   +  -14.42       -8.39   0.80    1.0   22.6ms
#   6   -1.118357398714      -15.18       -8.89   0.80    1.0   25.1ms
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.118357400607                   -4.40   0.80    1.0   12.6ms
#   2   -1.118357400953       -9.46       -5.42   0.80    1.0   19.9ms
#   3   -1.118357400956      -11.45       -6.17   0.80    1.0   31.6ms
#   4   -1.118357400956      -13.19       -7.09   0.80    1.0   17.1ms
#   5   -1.118357400956      -14.95       -7.86   0.80    1.0   17.5ms
#   6   -1.118357400956      -14.81       -8.35   0.80    1.0   18.4ms
#   7   -1.118357400956   +  -14.95       -9.45   0.80    1.0   18.7ms
# n     Energy            log10(ΔE)   log10(Δρ)   α      Diag   Δtime
# ---   ---------------   ---------   ---------   ----   ----   ------
#   1   -1.118357400956                  -10.08   0.80    1.0   10.5ms
#   2   -1.118357400956   +  -15.65      -11.02   0.80    1.0   22.0ms
#
# ┌─────┬─────────────────┬───────────┬────────────┬────────┐
# │   n │          Energy │ log10(ΔE) │ max(Force) │  Δtime │
# ├─────┼─────────────────┼───────────┼────────────┼────────┤
# │   3 │ -1.118357400956 │     -8.43 │ 1.09208e-8 │  716ms │
# └─────┴─────────────────┴───────────┴────────────┴────────┘

# %% [markdown]
# Structure after optimisation (note that the atom has wrapped around)

# %%
results.system
# Out:
# FlexibleSystem(H₂, periodicity = TTT):
#     cell_vectors      : [      10        0        0;
#                                 0       10        0;
#                                 0        0       10]u"a₀"
#
#     Atom(H,  [-0.0431826, 1.21372e-10, 4.7676e-11]u"a₀")
#     Atom(H,  [ 1.44318, 1.22699e-10, 5.20521e-11]u"a₀")

# %% [markdown]
# Compute final bond length:

# %%
rmin = norm(position(results.system[1]) - position(results.system[2]))
println("Optimal bond length: ", rmin)
# Out:
# Optimal bond length: 1.4863652636422149 a₀

# %% [markdown]
# Our results (1.486 Bohr) agrees with the
# [equivalent tutorial from ABINIT](https://docs.abinit.org/tutorial/base1/).
