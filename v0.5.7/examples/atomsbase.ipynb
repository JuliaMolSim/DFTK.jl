# %% [markdown]
# # AtomsBase integration

# %% [markdown]
# [AtomsBase.jl](https://github.com/JuliaMolSim/AtomsBase.jl) is a common interface
# for representing atomic structures in Julia. DFTK directly supports using such
# structures to run a calculation as is demonstrated here.

# %%
using DFTK
using AtomsBase
using Unitful
using UnitfulAtomic

# Construct a system in the AtomsBase world
a = 10.26u"bohr"  # Silicon lattice constant
lattice = a / 2 * [[0, 1, 1.],  # Lattice as vector of vectors
                   [1, 0, 1.],
                   [1, 1, 0.]]
atoms  = [:Si => ones(3)/8, :Si => -ones(3)/8]
system = periodic_system(atoms, lattice; fractional=true)
# Out:
# FlexibleSystem(Si₂, AtomsBase.Periodic, box=[[0.0, 5.13, 5.13], [5.13, 0.0, 5.13], [5.13, 5.13, 0.0]]u"a₀")

# %% [markdown]
# System is an AtomsBase-compatible system. To use it in DFTK,
# we attach pseudopotentials, construct a DFT model, discretise and solve:

# %%
system = attach_psp(system; family="hgh", functional="lda")

model  = model_LDA(system; temperature=1e-3)
basis  = PlaneWaveBasis(model; Ecut=15, kgrid=[4, 4, 4])
scfres = self_consistent_field(basis, tol=1e-8);
# Out:
# n     Energy            log10(ΔE)   log10(Δρ)   Diag
# ---   ---------------   ---------   ---------   ----
#   1   -7.921672900357                   -0.69    5.2
#   2   -7.926214848093       -2.34       -1.22    1.0
#   3   -7.926857887945       -3.19       -2.36    3.2
#   4   -7.926864977285       -5.15       -3.10    3.2
#   5   -7.926865048115       -7.15       -3.41    2.5
#   6   -7.926865092919       -7.35       -4.46    4.1
#   7   -7.926865092825   +  -10.03       -4.73    1.2

# %% [markdown]
# At any point we can also get back the DFTK model as an
# AtomsBase-compatible `AbstractSystem`:

# %%
newsystem = atomic_system(model)
# Out:
# FlexibleSystem(Si₂, AtomsBase.Periodic, box=[[0.0, 5.13, 5.13], [5.13, 0.0, 5.13], [5.13, 5.13, 0.0]]u"a₀")
